# %%
import os
path="/content/drive/MyDrive/Research"
os.chdir(path)
os.listdir(path)
# Out:
# ['kmeans_model.pkl',
#  'kmeans_model_100.pkl',
#  'haarcascade_frontalface_default.xml',
#  'decode.py',
#  'utils_tokenizer.py',
#  'utils.py',
#  'model_generator.py',
#  'data',
#  'Untitled0.ipynb',
#  '__pycache__',
#  'multimodal_model',
#  'models',
#  'runs',
#  'output3.15',
#  'output3.17',
#  'util_dataset.py',
#  'output3.18',
#  'output3.19',
#  'output3.21',
#  'output3.22',
#  'clipsum.py',
#  'train.py',
#  'Untitled1.ipynb',
#  'output3.26',
#  'output']

# %%
# !pip install transformers==4.27.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 85.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# ...

# %%
# !pip install scenedetect
# !pip install POT
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.7/114.7 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.0 MB/s eta 0:00:00
# ...

# %%
# !python train.py --epochs 1 --batch_size 2 --save_model_path 'multimodal_model/2024-Mar-21-08-28-10/2024-Mar-22-14-46-14/' --model_name 'E0- 0.556437.ckpt' --resume_training Ture
# !python train.py --epochs 1 --batch_size 2
# Out:
# ^C
# Traceback (most recent call last):
#   File "d:\Anaconda\envs\assignment2\lib\site-packages\transformers\utils\import_utils.py", line 1126, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "d:\Anaconda\envs\assignment2\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "d:\Anaconda\envs\assignment2\lib\site-packages\transformers\models\clip\feature_extraction_clip.py", line 20, in <module>
# ...

# %%
from google.colab import runtime
runtime.unassign()
